# %% [markdown]
# El index.html descargado del repositorio muestra mi pagina web, sin foto de perfil
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Mientras que en el index guardado en la carpeta, si funciona la foto de perfil, pero ya comprobe que esten bien la ruta de la foto o la sintaxis para agregarla.
#
# ![image.png](attachment:image.png)
